# %%
# %cd /content/drive/MyDrive/MultiQR_Hackathon/
# !git clone https://github.com/WongKinYiu/yolov9.git
# Out:
# /content/drive/MyDrive/MultiQR_Hackathon
# fatal: destination path 'yolov9' already exists and is not an empty directory.

# %%
# !pip install -r /content/drive/MyDrive/MultiQR_Hackathon/yolov9/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 21.1 MB/s eta 0:00:00
# ...

# %%
# import zipfile
# import os

# zip_path = "/content/drive/MyDrive/MultiQR_Hackathon/QR_Dataset.zip"
# extract_dir = "/content/drive/MyDrive/MultiQR_Hackathon/"

# os.makedirs(extract_dir, exist_ok=True)

# with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_dir)

# print("Dataset extracted to:", extract_dir)
# print("Files:", os.listdir(extract_dir))

# %%
import os

# %%
train_img_path = "/content/drive/MyDrive/MultiQR_Hackathon/QR_Dataset/images/train"
val_img_path = "/content/drive/MyDrive/MultiQR_Hackathon/QR_Dataset/images/val"

# %%
with open("/content/drive/MyDrive/MultiQR_Hackathon/QR_Dataset/train.txt","a+") as f:
  img_list = os.listdir(train_img_path)
  for img in img_list:
    f.write(os.path.join(train_img_path,img+'\n'))
  print("Done")
# Out:
# Done

# %%
with open("/content/drive/MyDrive/MultiQR_Hackathon/QR_Dataset/val.txt","a+") as f:
  img_list = os.listdir(val_img_path)
  for img in img_list:
    f.write(os.path.join(val_img_path,img+'\n'))
  print("Done")
# Out:
# Done

# %%
# %cp /content/drive/MyDrive/MultiQR_Hackathon/yolov9/data/coco.yaml /content/drive/MyDrive/MultiQR_Hackathon/yolov9/data/custom.yaml

# %% [markdown]
# Pretrained Weight for YOLOv9-S

# %%
# %cd /content/drive/MyDrive/MultiQR_Hackathon/yolov9/
# !wget "https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-s.pt"
# Out:
# /content/drive/MyDrive/MultiQR_Hackathon/yolov9
# --2025-10-01 09:02:53--  https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-s.pt
# Resolving github.com (github.com)... 140.82.114.3
# Connecting to github.com (github.com)|140.82.114.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# %cp /content/drive/MyDrive/MultiQR_Hackathon/yolov9/models/detect/yolov9-s.yaml /content/drive/MyDrive/MultiQR_Hackathon/yolov9/models/detect/custom-yolov9-s.yaml
